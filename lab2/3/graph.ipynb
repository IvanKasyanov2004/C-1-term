# %%
import numpy as np 
import matplotlib
from matplotlib import pyplot as plt

def MHK2(x, y, s_y=None, s_x=None, label=None, scattercolor=None, linecolor=None, showline=None, xlabel=None, ylabel=None, title=None):
    array_x = np.array(x)
    x_ = array_x.mean()

    array_y = np.array(y)
    y_ = array_y.mean()

    array_xy = np.array(x * y)
    xy_ = array_xy.mean()

    array_x2 = np.array(x * x)
    x2_ = array_x2.mean()

    array_y2 = np.array(y * y)
    y2_ = array_y2.mean()

    k = (xy_ - x_ * y_) / (x2_ - x_ ** 2)

    b = y_ - k * x_

    Dyy = y2_ - y_ ** 2
    Dxx = x2_ - x_ ** 2

    sigma_k = ((Dyy / Dxx - k  ** 2) / (len(x) - 2)) ** 0.5

    sigma_b = sigma_k * ((x2_) ** 0.5)

    plt.grid(True)
    plt.minorticks_on()
    plt.grid(which = 'minor', alpha = 0.2)
    
    plt.errorbar(x, y, xerr=s_x, yerr=s_y, linestyle="None", color=scattercolor)
    plt.scatter(x, y, s=6, color = scattercolor, label=label)
    
    if showline == True: 
        x0 = np.array([min(x), max(x)])
        y0 = k * x0 + b
        plt.plot(x0,y0, 'k--', color=linecolor)
    
    plt.title(title)
    plt.xlabel(xlabel)
    plt.ylabel(ylabel)
    plt.legend()

    print("k: ", k, "sigma_k: ", sigma_k, "b: ", b, "sigma_b: ", sigma_b)
    return(k, sigma_k, b, sigma_b)

# %%
f1 = open('shell_sort_1_time.txt', 'r')
lines1 = f1.readlines()
t1 = np.array(list(map(int, lines1[0].split())))
N1 = np.array(list(map(int, lines1[1].split())))
MHK2(N1, t1, showline=True, label = r"$ \alpha_{1} = 101$")
plt.grid(True)
plt.minorticks_on()
plt.grid(which = 'minor', alpha = 0.2)
plt.title("Сортировка Шелла 1 (100 запусков)")
plt.xlabel("N")
plt.ylabel("t, ms")
plt.show()
# Out:
# /var/folders/qq/pjggzry53mq7xbvhcjr59g800000gp/T/ipykernel_92865/4063428874.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x0,y0, 'k--', color=linecolor)
# k:  0.010133157894736842 sigma_k:  0.0002086785347424201 b:  -58.831578947368484 sigma_b:  24.997911670241443

# %%
f2 = open('shell_sort_1_swap.txt', 'r')
lines2 = f2.readlines()
s2 = np.array(list(map(int, lines2[0].split())))
N2 = np.array(list(map(int, lines2[1].split())))
MHK2(N2, s2, showline=True, label = "$k_1 = 21$")
plt.grid(True)
plt.minorticks_on()
plt.grid(which = 'minor', alpha = 0.2)
plt.title("Сортировка Шелла 1 (20 запусков)")
plt.xlabel("N")
plt.ylabel("s (среднее число перестановок)")
plt.show()
# Out:
# /var/folders/qq/pjggzry53mq7xbvhcjr59g800000gp/T/ipykernel_92865/4063428874.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x0,y0, 'k--', color=linecolor)
# k:  20.829093684210527 sigma_k:  0.4164169335323091 b:  -130930.33684210526 sigma_b:  49883.20305815054

# %%
f3 = open('shell_sort_2_time.txt', 'r')
lines3 = f3.readlines()
t3 = np.array(list(map(int, lines3[0].split())))
N3 = np.array(list(map(int, lines3[1].split())))
MHK2(N3, t3, showline=True, label = r"$ \alpha_{2} = 103$")
plt.grid(True)
plt.minorticks_on()
plt.grid(which = 'minor', alpha = 0.2)
plt.title("Сортировка Шелла 2 (100 запусков)")
plt.xlabel("N")
plt.ylabel("t, ms")
plt.show()
# Out:
# /var/folders/qq/pjggzry53mq7xbvhcjr59g800000gp/T/ipykernel_92865/4063428874.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x0,y0, 'k--', color=linecolor)
# k:  0.010243684210526316 sigma_k:  0.00020243886288630593 b:  -95.83684210526326 sigma_b:  24.250452109520623

# %%
f4 = open('shell_sort_2_swap.txt', 'r')
lines4 = f4.readlines()
s4 = np.array(list(map(int, lines4[0].split())))
N4 = np.array(list(map(int, lines4[1].split())))
MHK2(N4, s4, showline=True, label = "$k_2 = 19$")
plt.grid(True)
plt.minorticks_on()
plt.grid(which = 'minor', alpha = 0.2)
plt.title("Сортировка Шелла 2 (20 запусков)")
plt.xlabel("N")
plt.ylabel("s (среднее число перестановок)")
plt.show()
# Out:
# /var/folders/qq/pjggzry53mq7xbvhcjr59g800000gp/T/ipykernel_92865/4063428874.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x0,y0, 'k--', color=linecolor)
# k:  18.71734052631579 sigma_k:  0.1041902830521155 b:  -110610.70526315807 sigma_b:  12481.108782219118

# %%
f5 = open('shell_sort_3_time.txt', 'r')
lines5 = f5.readlines()
t5 = np.array(list(map(int, lines5[0].split())))
N5 = np.array(list(map(int, lines5[1].split())))
MHK2(N5, t5, showline=True, label = r"$ \alpha_{3} = 191$")
plt.grid(True)
plt.minorticks_on()
plt.grid(which = 'minor', alpha = 0.2)
plt.title("Сортировка Шелла 3 (100 запусков)")
plt.xlabel("N")
plt.ylabel("t, ms")
plt.show()
# Out:
# /var/folders/qq/pjggzry53mq7xbvhcjr59g800000gp/T/ipykernel_92865/4063428874.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x0,y0, 'k--', color=linecolor)
# k:  0.01919233082706767 sigma_k:  0.0004553160319938807 b:  -77.3947368421052 sigma_b:  54.54298384774951

# %%
f6 = open('shell_sort_3_swap.txt', 'r')
lines6 = f6.readlines()
s6 = np.array(list(map(int, lines6[0].split())))
N6 = np.array(list(map(int, lines6[1].split())))
MHK2(N6, s6, showline=True, label = "$k_3 = 28$")
plt.grid(True)
plt.minorticks_on()
plt.grid(which = 'minor', alpha = 0.2)
plt.title("Сортировка Шелла 3 (20 запусков)")
plt.xlabel("N")
plt.ylabel("s (среднее число перестановок)")
plt.show()
# Out:
# /var/folders/qq/pjggzry53mq7xbvhcjr59g800000gp/T/ipykernel_92865/4063428874.py:42: UserWarning: color is redundantly defined by the 'color' keyword argument and the fmt string "k--" (-> color='k'). The keyword argument will take precedence.
#   plt.plot(x0,y0, 'k--', color=linecolor)
# k:  27.69647180451128 sigma_k:  0.14317870888651815 b:  -158123.58947368432 sigma_b:  17151.590230505975

# %%
plt.plot(N1, t1, label=r"Вариант 1")
plt.plot(N3, t3, label=r"Вариант 2")
plt.plot(N5, t5, label=r"Вариант 3")

plt.grid(True)
plt.minorticks_on()
plt.grid(which = 'minor', alpha = 0.2)
plt.title("Сравнение сортировок Шелла (100 запусков)")
plt.xlabel("N")
plt.ylabel("t, ms")
plt.legend()
plt.show()
