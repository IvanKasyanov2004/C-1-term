# %%
import numpy as np
import matplotlib
from matplotlib import pyplot as plt

N1 = []
S1 = []
with open('2_1.txt', 'r') as file:
    for line in file:
        N1.append(float(line.split()[0]))
        S1.append(float(line.split()[1]))

N2 = []
S2 = []
with open('2_2.txt', 'r') as file:
    for line in file:
        N2.append(float(line.split()[0]))
        S2.append(float(line.split()[1]))

N3 = []
S3 = []
with open('2_3.txt', 'r') as file:
    for line in file:
        N3.append(float(line.split()[0]))
        S3.append(float(line.split()[1]))

N4 = []
S4 = []
with open('2_4.txt', 'r') as file:
    for line in file:
        N4.append(float(line.split()[0]))
        S4.append(float(line.split()[1]))

N5 = []
S5 = []
with open('2_5.txt', 'r') as file:
    for line in file:
        N5.append(float(line.split()[0]))
        S5.append(float(line.split()[1]))

N6 = []
S6 = []
with open('2_6.txt', 'r') as file:
    for line in file:
        N6.append(float(line.split()[0]))
        S6.append(float(line.split()[1]))

N7 = []
S7 = []
with open('2_7.txt', 'r') as file:
    for line in file:
        N7.append(float(line.split()[0]))
        S7.append(float(line.split()[1]))

N8 = []
S8 = []
with open('2_8.txt', 'r') as file:
    for line in file:
        N8.append(float(line.split()[0]))
        S8.append(float(line.split()[1]))

N9 = []
S9 = []
with open('2_9.txt', 'r') as file:
    for line in file:
        N9.append(float(line.split()[0]))
        S9.append(float(line.split()[1]))

N10 = []
S10 = []
with open('2_10.txt', 'r') as file:
    for line in file:
        N10.append(float(line.split()[0]))
        S10.append(float(line.split()[1]))

N11 = []
S11 = []
with open('2_11.txt', 'r') as file:
    for line in file:
        N11.append(float(line.split()[0]))
        S11.append(float(line.split()[1]))



plt.scatter([0],[0], color = (1,1,1), label = r"число атомов:")
plt.scatter(N2, S2, color = (1,0,0), label = r"20")
plt.scatter(N3, S3, color = (1,0.5,0), label = r"40")
plt.scatter(N4, S4, color = (1,1,0), label = r"60")
plt.scatter(N5, S5, color = (0,1,0), label = r"80")
plt.scatter(N6, S6, color = (0.6,0.5,0.5), label = r"100")
plt.scatter(N8, S8, color = (1,0.2,0.9), label = r"160")
plt.scatter(N9, S9, color = (0.3,0.2,0.9), label = r"200")
plt.scatter(N10, S10, color = (0,0.2,0.9), label = r"300")
plt.scatter(N11, S11, color = (0,0,0), label = r"400")


plt.title(r"График 2. steps(N) (200 запусков)")
plt.xlabel(r"N")
plt.ylabel(r"steps")
plt.grid(True)
plt.minorticks_on()
plt.grid(which = 'minor', alpha = 0.2)
plt.legend()

# %%
import numpy as np
import matplotlib
import matplotlib as mpl
import matplotlib.pyplot as plt

vegetables = [20, 40, 60, 80,
              100, 120, 160, 200, 300, 400]
farmers = N1

harvest = np.array([S2,
                    S3,
                    S4,
                    S5,
                    S6,
                    S7,
                    S8,
                    S9,
                    S10,
                    S11])


fig, ax = plt.subplots()
im = ax.imshow(harvest)

ax.set_xticks(np.arange(len(farmers)), labels=farmers)
ax.set_yticks(np.arange(len(vegetables)), labels=vegetables)

plt.setp(ax.get_xticklabels(), rotation=45, ha="right",
         rotation_mode="anchor")

ax.set_title("Heatmap steps(N, atoms number)")
ax.set_xlabel("N - сторона кристалла")
ax.set_ylabel("atoms number - количество атомов")
fig.tight_layout()
plt.show()
